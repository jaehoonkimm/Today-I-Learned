# %% [markdown]
# ### matplotlib 기초

# %%
from matplotlib import pyplot as plt

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075, 2862, 5979, 10289, 14956]

# %%
plt.title("Nominal GDP")
plt.ylabel("Billions of $")

plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.show()

# %%
plt.title("Nominal GDP")
plt.ylabel("Billions of $")

plt.plot(years, gdp, color='red', marker='x', linestyle='solid')
plt.show()

# %% [markdown]
# ### bar charts

# %%
movies = ["남산의 부장들", "겨울왕국", "설국열차", "기생충", "어바웃타임"]
final_audience_number = [4750104, 10296101, 9350192, 
                         10000249, 3396313]

# %%
# 막대 너비 default는 0.8이므로, 막대 가운데로 오도록 왼쪽 좌표에 0.1씩 추가
xs = [i + 0.1 for i, _ in enumerate(movies)]

# %%
import matplotlib.font_manager as fm
font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')

# %%
font_list[:]print (mpl.matplotlib_fname())
#'/Users/jaehoonkim/Library/Fonts/NanumGothicCoding.ttf'
# Out:
#   File "<ipython-input-35-f4fdfde5b7d0>", line 1
#     font_list[:]print (mpl.matplotlib_fname())
#                     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.font_manager as fm
path = '/Users/jaehoonkim/Library/Fonts/NanumGothicCoding.ttf'
fontprop = fm.FontProperties(fname=path, size=15)

# %%
plt.figure(figsize=(15,8))
plt.bar(xs, final_audience_number)
plt.ylabel("The final audience number", fontproperties=fontprop)
plt.title("Movies")
plt.xticks([i + 0.1 for i, _ in enumerate(movies)], movies, fontproperties=fontprop)
plt.show(fig)

# %% [markdown]
# ### line charts

# %%
variance = [1,2,4,8,16,32,64,128,256]
bias_squared = [256,128,64,32,16,8,4,2,1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# %%
plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias_squared, 'r-.', label='bias^2')
plt.plot(xs, total_error, 'b:', label="total error")

plt.legend(loc=9) #loc=9는 top center를 의미
plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# ### Scatterplots

# %%
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a','b','c','d','e','f','g','h','i']

plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
                xy=(friend_count, minute_count),
                xytext=(5, -5),
                textcoords='offset points')
plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")
plt.show()

# %%
#위 예시와 같은 scatter plot에서, 축의 범위를 matplotlib이 자동으로 설정하게 되면, 공정한 비교가 불가하다.
test_1 = [99, 90, 85, 97, 80]
test_2 = [100, 85, 60, 90, 70]

# %%
# x, y축이 동일한 범위를 가지지 않음 (matplotlib이 자동 할당)
plt.scatter(test_1, test_2)
plt.show()

# %%
# plt.axis("equal") 명령을 추가하여 x, y축을 동일하게 할당
plt.axis("equal")
plt.scatter(test_1, test_2)
plt.show()

# %% [markdown]
# ### Vector
# - 유한한 차원의 공간에 존재하는 점들
# - list를 통해 vector를 표현할 수 있으나, python list는 vector 연산이 불가...
# - numpy를 사용하여 해결
